# %% [markdown]
# ## Mondrian cp plots
#
# Make sure you have run the main mcp program beforehand as it saves the relevant results in ./experiment_logs.
#
# <!-- ```
# python mondrian_cp.py canonicalization=group_equivariant cp.score_fn=APS dataset.dataset_name=cifar10 experiment.inference.num_rotations=8 experiment.run_mode=test cp.alpha=0.1 checkpoint.checkpoint_path=./checkpoints checkpoint.checkpoint_name=canon_c8 hydra.job.chdir=False cp.num_resamples=10 cp.canon_cutoff=0.90 cp.mondrian.partitioning=label dataset.cp_experiments.class_conditional_joint=1 dataset.cp_experiments.shift_type=dirac
# ```
#
# ```
# python mondrian_cp.py canonicalization=group_equivariant cp.score_fn=APS dataset.dataset_name=cifar10 experiment.inference.num_rotations=8 experiment.run_mode=test cp.alpha=0.1 checkpoint.checkpoint_path=./checkpoints checkpoint.checkpoint_name=canon_c8 hydra.job.chdir=False cp.num_resamples=10 cp.canon_cutoff=0.90 cp.mondrian.partitioning=entropy dataset.cp_experiments.class_conditional_joint=1 dataset.cp_experiments.shift_type=normal
# ```
#
# ```
# python mondrian_cp.py canonicalization=group_equivariant cp.score_fn=APS dataset.dataset_name=cifar10 experiment.inference.num_rotations=8 experiment.run_mode=test cp.alpha=0.1 checkpoint.checkpoint_path=./checkpoints checkpoint.checkpoint_name=canon_c8 hydra.job.chdir=False cp.num_resamples=10 cp.canon_cutoff=0.90 cp.mondrian.partitioning=color dataset.cp_experiments.class_conditional_joint=1 dataset.cp_experiments.shift_type=var-gauss
# ``` -->

# %%
from plot_style import *
from plot_util import plot_coverage_mcp

plot_coverage_mcp(
    results_path="../experiment_logs/mondrian/label/dirac",
    target_partition="label",
    shift_type="dirac",
    calibration_size=6920/2,
    coverage=0.9
)

plot_coverage_mcp(
    results_path="../experiment_logs/mondrian/entropy/normal",
    target_partition="entropy",
    shift_type="normal",
    calibration_size=6900/2,
    coverage=0.9
)

plot_coverage_mcp(
    results_path="../experiment_logs/mondrian/color/var-gauss",
    target_partition="color",
    shift_type="var-gauss",
    calibration_size=6900/2,
    coverage=0.9
)
